# %% [markdown]
# <a href="https://colab.research.google.com/github/Krushang2194/Final_Project/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class SchoolApplication:
    def __init__(self, date, name, school, type, rating, tuition_fee, acceptance_rate):
        self.unique_id = id(self)
        self.date = date
        self.name = name
        self.school = school
        self.type = type
        self.rating = rating
        self.tuition_fee = tuition_fee
        self.acceptance_rate = acceptance_rate

    def __str__(self):
        return (f"{self.unique_id},{self.date},{self.name},{self.school},"
                f"{self.type},{self.rating},{self.tuition_fee},{self.acceptance_rate}")


class StemSchoolApplication(SchoolApplication):
    def __init__(self, date, name, school, rating, tuition_fee, acceptance_rate):
        super().__init__(date, name, school, "Stem", rating, tuition_fee, acceptance_rate)


class NonStemSchoolApplication(SchoolApplication):
    def __init__(self, date, name, school, rating, tuition_fee, acceptance_rate):
        super().__init__(date, name, school, "non-Stem", rating, tuition_fee, acceptance_rate)


class Caltech(StemSchoolApplication):
    def __init__(self, date, name, rating, tuition_fee, acceptance_rate):
        super().__init__(date, name, "Caltech", rating, tuition_fee, acceptance_rate)



class Wharton(NonStemSchoolApplication):
    def __init__(self, date, name, rating, tuition_fee, acceptance_rate):
        super().__init__(date, name, "Wharton", rating, tuition_fee, acceptance_rate)


class Yale(NonStemSchoolApplication):
    def __init__(self, date, name, rating, tuition_fee, acceptance_rate):
        super().__init__(date, name, "Yale", rating, tuition_fee, acceptance_rate)


# Testing the code with the examples provided
WhartonSchoolApplication = Wharton("2022-11-15", "nameA", 2, 641, 86.06)
print(str(WhartonSchoolApplication))
# Out:
# 134534327050176,2022-11-15,nameA,Wharton,non-Stem,2,641,86.06

# %%
import pickle

with open("SchoolApplicationpkl638250207.dat", 'rb') as fb:
    try:
        while True:
            objects = pickle.load(fb)
            print(len(objects))
    except EOFError:
        pass
# Out:
# 10000

# %%
with open('data.csv', 'w') as f:
  f.write("uniqueId,date,name,school,type,rating,tuition_fee,acceptance_rate\n")
  for obj in objects:
    f.write(str(obj)+'\n')

# %%
f = open('data.csv', 'r') #open for read
file_data = f.read()
print(file_data)
print(type(file_data))
f.close()
# Out:
# uniqueId,date,name,school,type,rating,tuition_fee,acceptance_rate
# 135246875174000,2022-03-16,LAW302,Wharton,non-Stem,1,15302,48.66
# 135246875165072,2022-04-24,MAN6332,Yale,non-Stem,2,15963,43.15
# 135246875173280,,LAW302,Wharton,non-Stem,2,18937,85.15
# 135246875168672,2022-04-21,LAW302,Wharton,non-Stem,2,24551,98.25
# 135246875172416,2022-05-20,MAN6332,Yale,non-Stem,2,22706,67.18
# 135246875168816,2022-06-06,LAW302,Wharton,non-Stem,2,17731,63.18
# 135246875165840,2022-02-03,LAW302,Wharton,non-Stem,3,16976,80.94
# 135246875169920,2022-03-15,MAN6332,Yale,non-Stem,1,17267,53.75
# 135246875166992,2022-03-23,MAN6382,Yale,non-Stem,,17226,76.54
# 135246875174192,2022-02-03,LAW302,Wharton,non-Stem,2,15492,50.63
# 135246875172800,2022-03-10,LAW302,Wharton,non-Stem,,,
# 135246875174768,2022-01-19,LAW342,Wharton,non-Stem,2,27109,85.56
# 135246875165696,,LAW102,Wharton,non-Stem,2,20871,59.7
# 135246875170976,2022-01-30,CS6332,Caltech,Stem,3,17785,90.27
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Enrollment_Data = pd.read_csv("data.csv")
Enrollment_Data
# Out:
#              uniqueId        date     name   school      type  rating  \
# 0     135246875174000  2022-03-16   LAW302  Wharton  non-Stem     1.0
# 1     135246875165072  2022-04-24  MAN6332     Yale  non-Stem     2.0
# 2     135246875173280         NaN   LAW302  Wharton  non-Stem     2.0
# 3     135246875168672  2022-04-21   LAW302  Wharton  non-Stem     2.0
# 4     135246875172416  2022-05-20  MAN6332     Yale  non-Stem     2.0
# ...               ...         ...      ...      ...       ...     ...
# 9995  135246861888064  2022-02-14   CS6332  Caltech      Stem     2.0
# 9996  135246861888112  2022-03-16   LAW342  Wharton  non-Stem     1.0
# 9997  135246861888160  2022-01-04   LAW342  Wharton  non-Stem     4.0
# 9998  135246861888208  2022-03-19   LAW102  Wharton  non-Stem     1.0
# 9999  135246861888256  2022-04-05  MAN6332     Yale  non-Stem     1.0
#
#       tuition_fee  acceptance_rate
# 0         15302.0            48.66
# 1         15963.0            43.15
# ...

# %%
Enrollment_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   uniqueId         10000 non-null  int64
#  1   date             9579 non-null   object
#  2   name             10000 non-null  object
#  3   school           10000 non-null  object
#  4   type             10000 non-null  object
#  5   rating           9573 non-null   float64
#  6   tuition_fee      9192 non-null   float64
#  7   acceptance_rate  9192 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 625.1+ KB

# %%
Enrollment_Data.isna().sum()
# Out:
# uniqueId             0
# date               421
# name                 0
# school               0
# type                 0
# rating             427
# tuition_fee        808
# acceptance_rate    808
# dtype: int64

# %%
print(Enrollment_Data['date'].mode()[0])
# Out:
# 2022-01-04

# %%
print(Enrollment_Data['rating'].mode()[0])
# Out:
# 2.0

# %%
skewness = Enrollment_Data['acceptance_rate'].skew()

print(f"Skewness of acceptance_rate: {skewness}")
# Out:
# Skewness of acceptance_rate: 0.009539530579362182

# %%
skewness_1 = Enrollment_Data['rating'].skew()

print(f"Skewness of rating: {skewness_1}")
# Out:
# Skewness of rating: 0.6147067014818948

# %%
print(Enrollment_Data.columns)
# Out:
# Index(['uniqueId', 'date', 'name', 'school', 'type', 'rating', 'tuition_fee',
#        'acceptance_rate'],
#       dtype='object')

# %%
cols = ['date', 'rating']

for column in cols:
    Enrollment_Data[column].fillna(Enrollment_Data[column].mode()[0], inplace=True)
# Out:
# <ipython-input-18-88c39697187d>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Enrollment_Data[column].fillna(Enrollment_Data[column].mode()[0], inplace=True)

# %%
print(Enrollment_Data.groupby('school')['rating'].apply(lambda x: x.mode()[0]))
# Use apply to calculate the mode for each group and select the first mode if there are multiple.
# The lambda function calculates the mode for each group ('x') and selects the first element ([0]) of the result.
# Out:
# school
# Caltech    2.0
# Wharton    2.0
# Yale       2.0
# Name: rating, dtype: float64

# %%
Enrollment_Data.isna().sum()
# Out:
# uniqueId             0
# date                 0
# name                 0
# school               0
# type                 0
# rating               0
# tuition_fee        808
# acceptance_rate    808
# dtype: int64

# %%
# Group data by 'school' and calculate the mean of 'tuition_fee' and 'acceptance_rate' for each school
mean_by_school = Enrollment_Data.groupby('school')[['tuition_fee', 'acceptance_rate']].mean()

# Display the results
print(mean_by_school)
# Out:
#           tuition_fee  acceptance_rate
# school
# Caltech  18707.785213        69.361619
# Wharton  18719.570799        69.540608
# Yale     18779.725449        69.622080

# %%
colms = ['tuition_fee', 'acceptance_rate']

# %%
Enrollment_Data['tuition_fee'] = Enrollment_Data.groupby('school')['tuition_fee'].transform(lambda x: x.fillna(x.mean()))
Enrollment_Data['acceptance_rate'] = Enrollment_Data.groupby('school')['acceptance_rate'].transform(lambda x: x.fillna(x.mean()))

# %%
Enrollment_Data.isna().sum()
# Out:
# uniqueId           0
# date               0
# name               0
# school             0
# type               0
# rating             0
# tuition_fee        0
# acceptance_rate    0
# dtype: int64

# %%
Enrollment_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   uniqueId         10000 non-null  int64
#  1   date             10000 non-null  object
#  2   name             10000 non-null  object
#  3   school           10000 non-null  object
#  4   type             10000 non-null  object
#  5   rating           10000 non-null  float64
#  6   tuition_fee      10000 non-null  float64
#  7   acceptance_rate  10000 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 625.1+ KB

# %%
book_info['genre'].value_counts().plot(kind='bar', color='orange')
plt.title('Number of books based on genre')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
# Create a bar chart
# x-coordinates of left sides of bars
# Group data by 'school' and count the occurrences of each school
enrollment_by_school = Enrollment_Data.groupby('school')['school'].count().reset_index(name='enrollment_count')

#plt.figure(figsize=(10, 6))
plt.bar(enrollment_by_school['school'], enrollment_by_school['enrollment_count'], color='darkorange')
plt.xlabel("School")
plt.ylabel("Number of Enrollments")
plt.title("Enrollments by School")
#plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Group data by 'type' and count the occurrences of each type
enrollment_by_type = Enrollment_Data.groupby('type')['type'].count().reset_index(name='enrollment_count')

# Create a bar chart
#plt.figure(figsize=(8, 6))  # Adjust figure size if needed
plt.bar(enrollment_by_type['type'], enrollment_by_type['enrollment_count'], color='darkorange')
plt.xlabel("Enrollment Type")
plt.ylabel("Number of Enrollments")
plt.title("Enrollments by Type")
plt.tight_layout()
plt.show()
